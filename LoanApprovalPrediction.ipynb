# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, VotingClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("LoanApprovalPrediction.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married  Dependents Education Self_Employed  \
# 593  LP002978  Female      No         0.0  Graduate            No
# 594  LP002979    Male     Yes         3.0  Graduate            No
# 595  LP002983    Male     Yes         1.0  Graduate            No
# 596  LP002984    Male     Yes         2.0  Graduate            No
# 597  LP002990  Female      No         0.0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 593             2900                0.0        71.0             360.0
# 594             4106                0.0        40.0             180.0
# 595             8072              240.0       253.0             360.0
# 596             7583                0.0       187.0             360.0
# 597             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 593             1.0         Rural           Y
# 594             1.0         Rural           Y
# ...

# %%
df.drop('Loan_ID', axis=1, inplace=True)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Gender               0.000000
# Married              0.000000
# Dependents           2.006689
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.511706
# Loan_Amount_Term     2.341137
# Credit_History       8.193980
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             598 non-null    object
#  1   Married            598 non-null    object
#  2   Dependents         586 non-null    float64
#  3   Education          598 non-null    object
#  4   Self_Employed      598 non-null    object
#  5   ApplicantIncome    598 non-null    int64
#  6   CoapplicantIncome  598 non-null    float64
#  7   LoanAmount         577 non-null    float64
#  8   Loan_Amount_Term   584 non-null    float64
#  9   Credit_History     549 non-null    float64
#  10  Property_Area      598 non-null    object
#  11  Loan_Status        598 non-null    object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 56.2+ KB

# %%
si=SimpleImputer(missing_values=np.nan,strategy="mean") 
df[['LoanAmount','Loan_Amount_Term','Credit_History']]=si.fit_transform(df[['LoanAmount','Loan_Amount_Term','Credit_History']])

# %%
df.isnull().sum()/len(df)*100
# Out:
# Gender               0.000000
# Married              0.000000
# Dependents           2.006689
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.000000
# Credit_History       0.000000
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 586 entries, 0 to 597
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             586 non-null    object
#  1   Married            586 non-null    object
#  2   Dependents         586 non-null    float64
#  3   Education          586 non-null    object
#  4   Self_Employed      586 non-null    object
#  5   ApplicantIncome    586 non-null    int64
#  6   CoapplicantIncome  586 non-null    float64
#  7   LoanAmount         586 non-null    float64
#  8   Loan_Amount_Term   586 non-null    float64
#  9   Credit_History     586 non-null    float64
#  10  Property_Area      586 non-null    object
#  11  Loan_Status        586 non-null    object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 59.5+ KB

# %%
sns.scatterplot(x='ApplicantIncome', y='LoanAmount', hue='Loan_Status', data=df)
plt.title("Income vs Loan Amount")
plt.show()

# %%
sns.countplot(x='Credit_History', hue='Loan_Status', data=df)
plt.title("Loan Approval vs Credit History")
plt.show()

# %%
sns.boxplot(x='Gender', y='ApplicantIncome', data=df)
plt.title("Income Distribution by Gender")
plt.xlabel("")
plt.show()

# %%
df.groupby('Gender')['Loan_Status'].value_counts(normalize=True)
# Out:
# Gender  Loan_Status
# Female  Y              0.669725
#         N              0.330275
# Male    Y              0.696017
#         N              0.303983
# Name: proportion, dtype: float64

# %%
df_num=df.select_dtypes([int,float])
df_cat=df.select_dtypes(object)

# %%
df_cat.head()
# Out:
#   Gender Married     Education Self_Employed Property_Area Loan_Status
# 0   Male      No      Graduate            No         Urban           Y
# 1   Male     Yes      Graduate            No         Rural           N
# 2   Male     Yes      Graduate           Yes         Urban           Y
# 3   Male     Yes  Not Graduate            No         Urban           Y
# 4   Male      No      Graduate            No         Urban           Y

# %%
for i in df_cat:
    le=LabelEncoder()
    df_cat[i]=le.fit_transform(df_cat[i])

# %%
df_cat.head()
# Out:
#    Gender  Married  Education  Self_Employed  Property_Area  Loan_Status
# 0       1        0          0              0              2            1
# 1       1        1          0              0              0            0
# 2       1        1          0              1              2            1
# 3       1        1          1              0              2            1
# 4       1        0          0              0              2            1

# %%
df=pd.concat([df_cat,df_num],axis=1)

# %%
df.head()
# Out:
#    Gender  Married  Education  Self_Employed  Property_Area  Loan_Status  \
# 0       1        0          0              0              2            1
# 1       1        1          0              0              0            0
# 2       1        1          0              1              2            1
# 3       1        1          1              0              2            1
# 4       1        0          0              0              2            1
#
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0         0.0             5849                0.0  144.968804
# 1         1.0             4583             1508.0  128.000000
# 2         0.0             3000                0.0   66.000000
# 3         0.0             2583             2358.0  120.000000
# 4         0.0             6000                0.0  141.000000
#
#    Loan_Amount_Term  Credit_History
# 0             360.0             1.0
# 1             360.0             1.0
# 2             360.0             1.0
# ...

# %%
x = df.drop(['Loan_Status'],axis=1)
y = df['Loan_Status']

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    405
# 0    181
# Name: count, dtype: int64

# %%
x,y= SMOTE().fit_resample(x,y)

# %%
y.value_counts()
# Out:
# Loan_Status
# 1    405
# 0    405
# Name: count, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=1)

# %%
scaler = StandardScaler()
xtrain_scaled = scaler.fit_transform(xtrain)
xtest_scaled = scaler.transform(xtest)

# %%
def my_model(model):
    model.fit(xtrain_scaled,ytrain)
    ypred=model.predict(xtest_scaled)
    
    print(classification_report(ytest,ypred))
    return model

# %% [markdown]
# ### Logistic Regression Model

# %%
logreg=LogisticRegression(solver="lbfgs")
my_model(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74        84
#            1       0.70      0.85      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.76      0.76      0.75       162
# weighted avg       0.77      0.75      0.75       162
# LogisticRegression()

# %%
logreg=LogisticRegression(solver= 'liblinear') 
my_model(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74        84
#            1       0.70      0.85      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.76      0.76      0.75       162
# weighted avg       0.77      0.75      0.75       162
# LogisticRegression(solver='liblinear')

# %%
logreg=LogisticRegression(solver= 'newton-cg') 
my_model(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74        84
#            1       0.70      0.85      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.76      0.76      0.75       162
# weighted avg       0.77      0.75      0.75       162
# LogisticRegression(solver='newton-cg')

# %%
logreg=LogisticRegression(solver= 'newton-cholesky') 
my_model(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74        84
#            1       0.70      0.85      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.76      0.76      0.75       162
# weighted avg       0.77      0.75      0.75       162
# LogisticRegression(solver='newton-cholesky')

# %%
logreg=LogisticRegression(solver= 'saga')
my_model(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74        84
#            1       0.70      0.85      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.76      0.76      0.75       162
# weighted avg       0.77      0.75      0.75       162
# LogisticRegression(solver='saga')

# %%
logreg=LogisticRegression(solver= 'sag')
my_model(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74        84
#            1       0.70      0.85      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.76      0.76      0.75       162
# weighted avg       0.77      0.75      0.75       162
# LogisticRegression(solver='sag')

# %% [markdown]
# #### Highest logreg model accuracy: for all solvers- 0.75

# %%
max_logreg_acc=0.75

# %% [markdown]
# ### KNN Model

# %%
knn= knn=KNeighborsClassifier()
my_model(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.61      0.67        84
#            1       0.65      0.77      0.70        78
#
#     accuracy                           0.69       162
#    macro avg       0.69      0.69      0.68       162
# weighted avg       0.69      0.69      0.68       162
# KNeighborsClassifier()

# %%
ac_list=[]
for i in range(2,31):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(xtrain_scaled,ytrain)
    ypred=knn.predict(xtest_scaled)
    
    ac=accuracy_score(ytest,ypred)
    ac_list.append(ac)

# %%
plt.figure(figsize=(5,5))
plt.xlabel("Values of K")
plt.ylabel("Accuracy")
plt.plot(range(2,31),ac_list,marker="*")
plt.show()

# %%
#Rebuild model w highest accuracy value of k
knn=KNeighborsClassifier(n_neighbors=24)
my_model(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.64      0.72        84
#            1       0.68      0.83      0.75        78
#
#     accuracy                           0.73       162
#    macro avg       0.75      0.74      0.73       162
# weighted avg       0.75      0.73      0.73       162
# KNeighborsClassifier(n_neighbors=24)

# %% [markdown]
# #### Highest knn model accuracy: KNeighborsClassifier(n_neighbors=24)- 0.73

# %%
max_knn_acc=0.73

# %% [markdown]
# ### SVM Model

# %%
svm= SVC(kernel='rbf')
my_model(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.63      0.72        84
#            1       0.68      0.86      0.76        78
#
#     accuracy                           0.74       162
#    macro avg       0.76      0.74      0.74       162
# weighted avg       0.76      0.74      0.74       162
# SVC()

# %%
svm=SVC(kernel='linear')
my_model(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.64      0.73        84
#            1       0.70      0.88      0.78        78
#
#     accuracy                           0.76       162
#    macro avg       0.78      0.76      0.76       162
# weighted avg       0.78      0.76      0.76       162
# SVC(kernel='linear')

# %%
svm=SVC(kernel='sigmoid')
my_model(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.65      0.72        84
#            1       0.69      0.83      0.76        78
#
#     accuracy                           0.74       162
#    macro avg       0.75      0.74      0.74       162
# weighted avg       0.75      0.74      0.74       162
# SVC(kernel='sigmoid')

# %%
svm=SVC(kernel='poly')
my_model(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.57      0.67        84
#            1       0.65      0.86      0.74        78
#
#     accuracy                           0.71       162
#    macro avg       0.73      0.72      0.71       162
# weighted avg       0.74      0.71      0.70       162
# SVC(kernel='poly')

# %%
para_grid={'C':[1,10],'gamma':[1,10],'kernel':['linear']}

# %%
gs=GridSearchCV(svm,para_grid,verbose=3)
gs.fit(xtrain_scaled,ytrain)
ypred=gs.predict(xtest_scaled)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.700 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.746 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.785 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.760 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.713 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=10, kernel=linear;, score=0.700 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=10, kernel=linear;, score=0.746 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=10, kernel=linear;, score=0.785 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=10, kernel=linear;, score=0.760 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=10, kernel=linear;, score=0.713 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.700 total time=   0.0s
# ...

# %%
gs.best_params_
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'linear'}

# %%
svm=gs.best_estimator_
my_model(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.64      0.73        84
#            1       0.70      0.88      0.78        78
#
#     accuracy                           0.76       162
#    macro avg       0.78      0.76      0.76       162
# weighted avg       0.78      0.76      0.76       162
# SVC(C=1, gamma=1, kernel='linear')

# %% [markdown]
# #### Highest svm model accuracy: SVC {'C': 1, 'gamma': 1, 'kernel': 'linear'}- 0.76

# %%
max_svm_acc=0.76

# %% [markdown]
# ### Decision Tree Classifier

# %%
dt= DecisionTreeClassifier()
my_model(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.75        84
#            1       0.73      0.74      0.74        78
#
#     accuracy                           0.75       162
#    macro avg       0.75      0.75      0.75       162
# weighted avg       0.75      0.75      0.75       162
# DecisionTreeClassifier()

# %%
max_dt_acc=0.75

# %% [markdown]
# ### Ensemble Learning Model

# %%
bg= BaggingClassifier(LogisticRegression())
my_model(bg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.65      0.73        84
#            1       0.70      0.86      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.77      0.76      0.75       162
# weighted avg       0.77      0.75      0.75       162
# BaggingClassifier(estimator=LogisticRegression())

# %%
bg= BaggingClassifier(DecisionTreeClassifier())
my_model(bg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72        84
#            1       0.70      0.73      0.71        78
#
#     accuracy                           0.72       162
#    macro avg       0.72      0.72      0.72       162
# weighted avg       0.72      0.72      0.72       162
# BaggingClassifier(estimator=DecisionTreeClassifier())

# %%
rf= RandomForestClassifier()
my_model(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75        84
#            1       0.71      0.83      0.77        78
#
#     accuracy                           0.76       162
#    macro avg       0.77      0.76      0.76       162
# weighted avg       0.77      0.76      0.76       162
# RandomForestClassifier()

# %%
models=[]
models.append(("LR",LogisticRegression()))
models.append(("DT",DecisionTreeClassifier()))

# %%
models
# Out:
# [('LR', LogisticRegression()), ('DT', DecisionTreeClassifier())]

# %%
vt= VotingClassifier(estimators=models)
my_model(vt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.74        84
#            1       0.73      0.69      0.71        78
#
#     accuracy                           0.73       162
#    macro avg       0.73      0.73      0.73       162
# weighted avg       0.73      0.73      0.73       162
# VotingClassifier(estimators=[('LR', LogisticRegression()),
#                              ('DT', DecisionTreeClassifier())])

# %%
ada= AdaBoostClassifier()
my_model(ada)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.62      0.72        84
#            1       0.68      0.88      0.77        78
#
#     accuracy                           0.75       162
#    macro avg       0.77      0.75      0.74       162
# weighted avg       0.77      0.75      0.74       162
# AdaBoostClassifier()

# %%
gbc= GradientBoostingClassifier()
my_model(gbc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.64      0.72        84
#            1       0.69      0.85      0.76        78
#
#     accuracy                           0.74       162
#    macro avg       0.75      0.74      0.74       162
# weighted avg       0.76      0.74      0.74       162
# GradientBoostingClassifier()

# %%
xgb= XGBClassifier()
my_model(xgb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77        84
#            1       0.75      0.79      0.77        78
#
#     accuracy                           0.77       162
#    macro avg       0.77      0.77      0.77       162
# weighted avg       0.77      0.77      0.77       162
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
# ...

# %% [markdown]
# #### Highest ensemble model accuracy: xgb classifier- 0.77

# %%
max_ensemble_acc=0.77

# %%
model_accuracies = {
    "Logistic Regression": max_logreg_acc,
    "KNN": max_knn_acc,
    "SVM": max_svm_acc,
    "Decision Tree": max_dt_acc,
    "Ensemble Model": max_ensemble_acc
}

# %%
for model, acc in model_accuracies.items():
    print(model, ":", acc)
# Out:
# Logistic Regression : 0.76
# KNN : 0.73
# SVM : 0.76
# Decision Tree : 0.75
# Ensemble Model : 0.77

# %%
data = pd.DataFrame({
    "Model": models,
    "Accuracy": accuracies
})
sns.barplot(x="Model", y="Accuracy", data=data)
plt.title("Accuracy Comparison of ML Models")
plt.ylim(0,1)
plt.xticks(rotation=45)
plt.xlabel("")
plt.show()
